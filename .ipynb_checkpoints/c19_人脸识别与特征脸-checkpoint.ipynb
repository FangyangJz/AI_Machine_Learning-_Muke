# %% [markdown]
# # 特征脸数据导入和预览

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from sklearn.datasets import fetch_lfw_people

# %%
path = os.getcwd()
faces = fetch_lfw_people(data_home=path)

# %%
faces.keys()
# Out:
# dict_keys(['data', 'images', 'target', 'target_names', 'DESCR'])

# %%
faces.data.shape
# Out:
# (13233, 2914)

# %%
faces.images.shape
# Out:
# (13233, 62, 47)

# %%
random_indexes = np.random.permutation(len(faces.data))
random_indexes.shape
# Out:
# (13233,)

# %%
X = faces.data[random_indexes]
example_faces = X[:36, :]
example_faces.shape
# Out:
# (36, 2914)

# %%
def plot_faces(faces):
    fig, axes = plt.subplots(6,6, figsize=(10,10),
                           subplot_kw={'xticks':[], 'yticks':[]},
                           gridspec_kw=dict(hspace=0.1, wspace=0.1))
    for i, ax in enumerate(axes.flat):
        ax.imshow(faces[i].reshape(62, 47), cmap='bone')
    plt.show()

# %%
plot_faces(example_faces)

# %%
faces.target_names[:10]
# Out:
# array(['AJ Cook', 'AJ Lamas', 'Aaron Eckhart', 'Aaron Guiel',
#        'Aaron Patterson', 'Aaron Peirsol', 'Aaron Pena', 'Aaron Sorkin',
#        'Aaron Tippin', 'Abba Eban'], dtype='<U35')

# %% [markdown]
# # 特征脸

# %%
from sklearn.decomposition import PCA

# %%
# %%time
# randomized对大量数据处理快, 
# 没有指定n_components, 求出所有主成分
pca = PCA(svd_solver='randomized')
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_.shape
# Out:
# (2914, 2914)

# %%
plot_faces(pca.components_[:36, :])
